# %%
import pandas as pd

df = pd.read_csv("bank_transactions.csv")

df.head()
# Out:
#   TransactionID CustomerID CustomerDOB CustGender CustLocation  \
# 0            T1   C5841053     10/1/94          F   JAMSHEDPUR
# 1            T2   C2142763      4/4/57          M      JHAJJAR
# 2            T3   C4417068    26/11/96          F       MUMBAI
# 3            T4   C5342380     14/9/73          F       MUMBAI
# 4            T5   C9031234     24/3/88          F  NAVI MUMBAI
#
#    CustAccountBalance TransactionDate  TransactionTime  \
# 0            17819.05          2/8/16           143207
# 1             2270.69          2/8/16           141858
# 2            17874.44          2/8/16           142712
# 3           866503.21          2/8/16           142714
# 4             6714.43          2/8/16           181156
#
#    TransactionAmount (INR)
# 0                     25.0
# 1                  27999.0
# 2                    459.0
# 3                   2060.0
# 4                   1762.5

# %%
df.shape
# Out:
# (1048567, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048567 entries, 0 to 1048566
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   TransactionID            1048567 non-null  object
#  1   CustomerID               1048567 non-null  object
#  2   CustomerDOB              1045170 non-null  object
#  3   CustGender               1047467 non-null  object
#  4   CustLocation             1048416 non-null  object
#  5   CustAccountBalance       1046198 non-null  float64
#  6   TransactionDate          1048567 non-null  object
#  7   TransactionTime          1048567 non-null  int64
#  8   TransactionAmount (INR)  1048567 non-null  float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 72.0+ MB

# %%
df.isnull().sum()
# Out:
# TransactionID                 0
# CustomerID                    0
# CustomerDOB                3397
# CustGender                 1100
# CustLocation                151
# CustAccountBalance         2369
# TransactionDate               0
# TransactionTime               0
# TransactionAmount (INR)       0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# TransactionID              0
# CustomerID                 0
# CustomerDOB                0
# CustGender                 0
# CustLocation               0
# CustAccountBalance         0
# TransactionDate            0
# TransactionTime            0
# TransactionAmount (INR)    0
# dtype: int64

# %%
df.describe()
# Out:
#        CustAccountBalance  TransactionTime  TransactionAmount (INR)
# count        1.041614e+06     1.041614e+06             1.041614e+06
# mean         1.149986e+05     1.571221e+05             1.566096e+03
# std          8.467609e+05     5.126352e+04             6.561464e+03
# min          0.000000e+00     0.000000e+00             0.000000e+00
# 25%          4.728140e+03     1.240410e+05             1.600000e+02
# 50%          1.676852e+04     1.642470e+05             4.575000e+02
# 75%          5.742885e+04     2.000220e+05             1.200000e+03
# max          1.150355e+08     2.359590e+05             1.560035e+06

# %%
df['CustLocation'].value_counts().head(10)
# Out:
# CustLocation
# MUMBAI       101997
# NEW DELHI     84143
# BANGALORE     81330
# GURGAON       73594
# DELHI         70549
# NOIDA         32656
# CHENNAI       29840
# PUNE          25690
# HYDERABAD     22976
# THANE         21397
# Name: count, dtype: int64

# %%
df['CustGender'].value_counts()
# Out:
# CustGender
# M    760978
# F    280635
# T         1
# Name: count, dtype: int64

# %%
df['TransactionAmount (INR)'].max()
# Out:
# 1560034.99

# %%
df.nlargest(10, 'TransactionAmount (INR)')
# Out:
#        TransactionID CustomerID CustomerDOB CustGender       CustLocation  \
# 399117       T399118   C7319271     25/5/76          M            GURGAON
# 579014       T579015   C6677159      8/1/78          F               PUNE
# 532036       T532037   C4141768     16/8/76          M          NEW DELHI
# 749353       T749354   C8217728    10/12/69          M             MUMBAI
# 56540         T56541   C1830891     17/5/85          F            KOLKATA
# 846924       T846925   C6549785     18/9/88          F              NOIDA
# 173291       T173292   C5036642    13/11/89          M          NEW DELHI
# 356306       T356307   C4328064      5/1/69          F              DELHI
# 152735       T152736   C1425138    24/12/83          M             MUMBAI
# 403383       T403384   C5833636    1/1/1800          M  PALAKKARAI TRICHY
#
#         CustAccountBalance TransactionDate  TransactionTime  \
# 399117            42487.89         18/8/16           132711
# ...

# %%
df['TransactionDate'].value_counts().head(10)
# Out:
# TransactionDate
# 7/8/16     27084
# 13/8/16    26738
# 4/9/16     26420
# 6/8/16     26416
# 3/9/16     26292
# 10/9/16    25628
# 14/8/16    25407
# 11/9/16    25355
# 15/8/16    24020
# 21/8/16    22833
# Name: count, dtype: int64

# %%
df.to_csv("clean_bank_transactions.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df.to_csv("clean_bank_transactions.csv", index=False)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...
